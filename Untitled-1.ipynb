# %%
with open("C:\\Users\\lijm1\\Desktop\\test.log", mode='rb') as file: # b is important -> binary
    fileContent = file.read()

# %%
import numpy as np

f = open("C:\\Users\\lijm1\\Desktop\\test.log", "r")
a = np.fromfile(f, dtype=np.uint8)

# %%
a.shape
# Out:
# (75518,)

# %%
test = np.pad(a, (0,76800-a.shape[0]), 'constant', constant_values=0)

# %%
test.shape
# Out:
# (76800,)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(test.reshape((240,320)), cmap="gray")

# %%
import numpy as np
import matplotlib.pyplot as plt
image = np.load('img.npy')
plt.imshow(image, cmap='gray')
